# %% [markdown]
# # RiskOptima

# %% [markdown]
# ## Workflow overview
#
# This notebook walks through the portfolio optimization project. It starts with a weighted asset table, downloads market data, reviews correlation and allocation charts, then compares Monte Carlo efficient-frontier analysis with mean-variance and machine-learning based optimization. The goal is to show how RiskOptima turns asset returns into portfolio construction decisions.

# %%
# !pip install --upgrade riskoptima
# Out:
# Requirement already satisfied: riskoptima in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (2.3.1)
# Requirement already satisfied: matplotlib>=3.8.4 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (3.10.8)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (2.3.5)
# Requirement already satisfied: pandas>=2.1.4 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.5.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (1.8.0)
# Requirement already satisfied: scipy>=1.13.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (0.13.2)
# Requirement already satisfied: squarify>=0.4.4 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (0.4.4)
# Requirement already satisfied: statsmodels>=0.14.2 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (0.14.6)
# Requirement already satisfied: xgboost>=2.1.3 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (3.1.2)
# Requirement already satisfied: yfinance>=0.2.54 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from riskoptima) (0.2.57)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jordi\appdata\roaming\python\python311\site-packages (from matplotlib>=3.8.4->riskoptima) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from matplotlib>=3.8.4->riskoptima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from pandas>=2.1.4->riskoptima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from pandas>=2.1.4->riskoptima) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.4->riskoptima) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from scikit-learn>=1.5.1->riskoptima) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from scikit-learn>=1.5.1->riskoptima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from statsmodels>=0.14.2->riskoptima) (1.0.2)
# Requirement already satisfied: requests>=2.31 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (4.5.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from yfinance>=0.2.54->riskoptima) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.54->riskoptima) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.54->riskoptima) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from requests>=2.31->yfinance>=0.2.54->riskoptima) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from requests>=2.31->yfinance>=0.2.54->riskoptima) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from requests>=2.31->yfinance>=0.2.54->riskoptima) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jordi\anaconda3\envs\riskoptima\lib\site-packages (from requests>=2.31->yfinance>=0.2.54->riskoptima) (2025.11.12)

# %%
import pandas as pd
from riskoptima import RiskOptima

import warnings
warnings.filterwarnings(
    "ignore", 
    category=FutureWarning, 
    message=".*DataFrame.std with axis=None is deprecated.*"
)

# Define your current porfolio with your weights and company names
asset_data = [
    {"Asset": "MO",    "Weight": 0.04, "Label": "Altria Group Inc.",       "MarketCap": 110.0e9},
    {"Asset": "NWN",   "Weight": 0.14, "Label": "Northwest Natural Gas",   "MarketCap": 1.8e9},
    {"Asset": "BKH",   "Weight": 0.01, "Label": "Black Hills Corp.",         "MarketCap": 4.5e9},
    {"Asset": "ED",    "Weight": 0.01, "Label": "Con Edison",                "MarketCap": 30.0e9},
    {"Asset": "PEP",   "Weight": 0.09, "Label": "PepsiCo Inc.",              "MarketCap": 255.0e9},
    {"Asset": "NFG",   "Weight": 0.16, "Label": "National Fuel Gas",         "MarketCap": 5.6e9},
    {"Asset": "KO",    "Weight": 0.06, "Label": "Coca-Cola Company",         "MarketCap": 275.0e9},
    {"Asset": "FRT",   "Weight": 0.28, "Label": "Federal Realty Inv. Trust", "MarketCap": 9.8e9},
    {"Asset": "GPC",   "Weight": 0.16, "Label": "Genuine Parts Co.",         "MarketCap": 25.3e9},
    {"Asset": "MSEX",  "Weight": 0.05, "Label": "Middlesex Water Co.",       "MarketCap": 2.4e9}
]
asset_table = pd.DataFrame(asset_data)

capital = 100_000

asset_table['Portfolio'] = asset_table['Weight'] * capital

ANALYSIS_START_DATE = RiskOptima.get_previous_year_date(RiskOptima.get_previous_working_day(), 1)
ANALYSIS_END_DATE   = RiskOptima.get_previous_working_day()
BENCHMARK_INDEX     = 'SPY'
RISK_FREE_RATE      = 0.05
NUMBER_OF_WEIGHTS   = 10_000
NUMBER_OF_MC_RUNS   = 1_000

print(asset_table)
print(RiskOptima.VERSION)
# Out:
#   Asset  Weight                      Label     MarketCap  Portfolio
# 0    MO    0.04          Altria Group Inc.  1.100000e+11     4000.0
# 1   NWN    0.14      Northwest Natural Gas  1.800000e+09    14000.0
# 2   BKH    0.01          Black Hills Corp.  4.500000e+09     1000.0
# 3    ED    0.01                 Con Edison  3.000000e+10     1000.0
# 4   PEP    0.09               PepsiCo Inc.  2.550000e+11     9000.0
# 5   NFG    0.16          National Fuel Gas  5.600000e+09    16000.0
# 6    KO    0.06          Coca-Cola Company  2.750000e+11     6000.0
# 7   FRT    0.28  Federal Realty Inv. Trust  9.800000e+09    28000.0
# 8   GPC    0.16          Genuine Parts Co.  2.530000e+10    16000.0
# 9  MSEX    0.05        Middlesex Water Co.  2.400000e+09     5000.0
# 2.7.0

# %% [markdown]
# # Create Correlation Matrix

# %%
RiskOptima.build_correlation_matrix(asset_table, ANALYSIS_START_DATE, ANALYSIS_END_DATE)
# Out:
# Ticker       BKH        ED       FRT       GPC        KO        MO      MSEX  \
# Ticker
# BKH     1.000000  0.414879  0.279375  0.143470  0.200200  0.203274  0.306509
# ED      0.414879  1.000000  0.284791  0.187394  0.420607  0.374930  0.480805
# FRT     0.279375  0.284791  1.000000  0.252422  0.250095  0.148028  0.332501
# GPC     0.143470  0.187394  0.252422  1.000000  0.182209  0.147009  0.208631
# KO      0.200200  0.420607  0.250095  0.182209  1.000000  0.408149  0.258993
# MO      0.203274  0.374930  0.148028  0.147009  0.408149  1.000000  0.205841
# MSEX    0.306509  0.480805  0.332501  0.208631  0.258993  0.205841  1.000000
# NFG     0.282346  0.361903  0.123310  0.101075  0.192944  0.228462  0.229640
# NWN     0.497698  0.575592  0.300431  0.193196  0.302488  0.243920  0.399324
# PEP     0.221290  0.397538  0.204608  0.322236  0.555448  0.412786  0.258137
#
# Ticker       NFG       NWN       PEP
# Ticker
# BKH     0.282346  0.497698  0.221290
# ED      0.361903  0.575592  0.397538
# FRT     0.123310  0.300431  0.204608
# GPC     0.101075  0.193196  0.322236
# KO      0.192944  0.302488  0.555448
# MO      0.228462  0.243920  0.412786
# MSEX    0.229640  0.399324  0.258137
# NFG     1.000000  0.418740  0.213403
# NWN     0.418740  1.000000  0.309542
# PEP     0.213403  0.309542  1.000000

# %% [markdown]
# ## Create Portfolio Area Chart

# %%
RiskOptima.create_portfolio_area_chart(
    asset_table,
    end_date=ANALYSIS_END_DATE,
    lookback_days=2,
    title="Portfolio Area Chart"
)
# Out:
#   Asset  Close(T-2)    Close(T)  2d % Change
# 0    MO   74.300003   74.980003     0.915209
# 1   NWN  109.809998  112.089996     2.076313
# 2   BKH  125.589996  125.050003    -0.429965
# 3    ED  119.120003  120.370003     1.049362
# 4   PEP   81.970001   82.199997     0.280585
# 5   NFG   72.989998   72.169998    -1.123441
# 6    KO   56.009998   56.580002     1.017682
# 7   FRT   80.879997   82.860001     2.448075
# 8   GPC   50.590000   51.560001     1.917377
# 9  MSEX  135.000000  135.649994     0.481477

# %% [markdown]
# ## Efficient Frontier with Monte Carlo Simulation

# %%
_, _, _ = RiskOptima.plot_efficient_frontier_monte_carlo(
    asset_table,
    start_date=ANALYSIS_START_DATE,
    end_date=ANALYSIS_END_DATE,
    risk_free_rate=RISK_FREE_RATE,
    num_portfolios=NUMBER_OF_WEIGHTS,
    market_benchmark=BENCHMARK_INDEX,
    set_ticks=False,
    x_pos_table=1.15,    # Position for the weight table on the plot
    y_pos_table=0.52,    # Position for the weight table on the plot
)

# %% [markdown]
# ## Portfolio Optimization using Mean Variance and Machine Learning

# %%
RiskOptima.run_portfolio_optimization_mv_ml(
    asset_table=asset_table,
    training_start_date='2022-01-01',
    training_end_date='2023-11-27',
    model_type='Linear Regression',    
    risk_free_rate=RISK_FREE_RATE,
    num_portfolios=100000,
    market_benchmark=[BENCHMARK_INDEX],
    max_volatility=0.25,
    min_weight=0.03,
    max_weight=0.2
)

# %% [markdown]
# ## Portfolio Optimization using Probability Analysis

# %%
RiskOptima.run_portfolio_probability_analysis(
    asset_table=asset_table,
    analysis_start_date=ANALYSIS_START_DATE,
    analysis_end_date=ANALYSIS_END_DATE,
    benchmark_index=BENCHMARK_INDEX,
    risk_free_rate=RISK_FREE_RATE,
    number_of_portfolio_weights=NUMBER_OF_WEIGHTS,
    trading_days_per_year=RiskOptima.get_trading_days(),
    number_of_monte_carlo_runs=NUMBER_OF_MC_RUNS
)
