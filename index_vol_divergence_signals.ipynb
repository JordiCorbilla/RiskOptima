# %%
from riskoptima import RiskOptima
print(RiskOptima.VERSION)

df_signals, df_exits, returns = RiskOptima.run_index_vol_divergence_signals()
# Out:
# 1.31.0
# YF.download() has changed argument auto_adjust default to True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from riskoptima import RiskOptima
#       2 print(RiskOptima.VERSION)
# ----> 4 df_signals, df_exits, returns = RiskOptima.run_index_vol_divergence_signals()
#
# File C:\repo\portfolio_risk_kit\riskoptima\riskoptima.py:3383, in RiskOptima.run_index_vol_divergence_signals(start_date, end_date, symbol_spy, symbol_vix, ma_window)
#    3381 returns = RiskOptima.calculate_total_returns(df_signals, df_exits)
#    3382 # 4) Plot and summarize
# -> 3383 RiskOptima.plot_exit_strategy(df, df_signals, df_exits, returns)
#    3385 # Return them if needed for further processing
#    3386 return df_signals, df_exits, returns
#
# TypeError: RiskOptima.plot_exit_strategy() missing 1 required positional argument: 'end_date'
